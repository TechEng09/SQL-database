# %%
import mysql.connector
import pandas as pd

# %%
db_config = {
    'user':'adeboz',
    'password':'Alfaawwal@09',
    'host': 'localhost',
    'database': 'myown'  
}

# %%
def upload_csv_to_mysql(filename, table_name):
    data = pd.read_csv(filename)

    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor()

    for _, row in data.iterrows():
        cursor.execute(
            f"INSERT INTO {table_name} (id, name, age, email) VALUES (%s, %s, %s, %s)",
            (row['id'], row['name'], row['age'], row['email'])
        )
    
    conn.commit()
    cursor.close()
    conn.close()

    print("Data Uploaded Successfully")

upload_csv_to_mysql('new.csv', 'users')
# Out:
# Data Uploaded Successfully

# %%
data_1 = pd.read_csv("video_game_reviews.csv")
data_1.head()
# Out:
#            Game Title  User Rating Age Group Targeted  Price     Platform  \
# 0  Grand Theft Auto V         36.4           All Ages  41.41           PC
# 1          The Sims 4         38.3             Adults  57.56           PC
# 2           Minecraft         26.8              Teens  44.93           PC
# 3   Bioshock Infinite         38.4           All Ages  48.29       Mobile
# 4     Half-Life: Alyx         30.1             Adults  55.49  PlayStation
#
#   Requires Special Device   Developer        Publisher  Release Year  \
# 0                      No  Game Freak       Innersloth          2015
# 1                      No    Nintendo  Electronic Arts          2015
# 2                     Yes      Bungie           Capcom          2012
# 3                     Yes  Game Freak         Nintendo          2015
# 4                     Yes  Game Freak       Epic Games          2022
#
#        Genre Multiplayer  Game Length (Hours) Graphics Quality  \
# ...

# %%
# to upload this large file to a sql database
#we start with creating a table first 

mydb =mysql.connector.connect(**db_config)

mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE GAMES (game_title VARCHAR(255), user_rating NUMERIC (10), age_group_target VARCHAR(255), " \
"price NUMERIC(10), platform VARCHAR(255), requires_special_device VARCHAR(255), developer VARCHAR(255)," \
"publisher VARCHAR(255), release_year INT(10), genre VARCHAR(255), multiplayer VARCHAR (255), game_length NUMERIC(10)," \
"graphics_quality VARCHAR(255), soundtrack_quality VARCHAR(255), story_quality VARCHAR(255), user_review_text VARCHAR(255)," \
"game_mode VARCHAR(255), min_of_players INT(10))")

# %%
# to upload this large file to a sql database
#we start with creating a table first 

mybd =mysql.connector.connect(**db_config)

mycursor = mybd.cursor()

mycursor.execute("CREATE TABLE info_games (game_title VARCHAR(255), user_rating FLOAT(10), age_group_target VARCHAR(255), " \
"price FLOAT(10), platform VARCHAR(255), requires_special_device VARCHAR(255), developer VARCHAR(255)," \
"publisher VARCHAR(255), release_year INT(10), genre VARCHAR(255), multiplayer VARCHAR (255), game_length FLOAT(10)," \
"graphics_quality VARCHAR(255), soundtrack_quality VARCHAR(255), story_quality VARCHAR(255), user_review_text VARCHAR(255)," \
"game_mode VARCHAR(255), min_of_players INT(10))")

# %%
def upload_to_sql(csv_name, table):
    data = pd.read_csv(csv_name)

    conn = mysql.connector.connect(**db_config)
    cursor = conn.cursor()

    for _, row in data.iterrows():
        cursor.execute(
            f"INSERT INTO {table} (game_title, user_rating, age_group_target, price, platform, requires_special_device, developer, publisher, release_year, genre, multiplayer, game_length, graphics_quality, soundtrack_quality, story_quality, user_review_text, game_mode, min_of_players) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)",
            (row["Game Title"], row["User Rating"], row["Age Group Targeted"], row["Price"], row["Platform"], row["Requires Special Device"], row["Developer"], row["Publisher"], row["Release Year"], row["Genre"], row["Multiplayer"], row["Game Length (Hours)"], row["Graphics Quality"], row["Soundtrack Quality"], row["Story Quality"], row["User Review Text"], row["Game Mode"], row["Min Number of Players"])
            )
        
    conn.commit()
    cursor.close()
    conn.close()

    print("Data uploaded Successfully")

upload_to_sql("video_game_reviews.csv", "info_games")
# Out:
# Data uploaded Successfully
